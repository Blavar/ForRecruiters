# %%
'''
An implementation of ID3 algorithm (i think) for building decision trees.

Data was borrowed from here:
https://www.kaggle.com/datasets/pablomgomez21/drugs-a-b-c-x-y-for-decision-trees

To be completely honest, I don't know if I can use this data as part of the portfolio, but here we are.
Then again, I don't see any Data Science Police around, do you? You better not...




'''
import matplotlib.pyplot as plt
import pandas as pd

from math import log2

from factory import Factory

df = pd.read_csv( 'drug.csv')

#entropy function
def H( probs ):
    entropy = 0
    for p in probs:
        #just in case
        try:
            res += p * log2(p)
        except:
            continue

    return -entropy

#class that given data and target column, returns
class Kek:
    def __init__(self, df, target):
        self.QUANTILES = 20
        self.df = df
        target = target

        self.h = H( self.get_probs( self.df ) )

    
    def get_probs(self, split):
        #build a list of probs
        total = split.size
        counts = split.value_counts()

        res = [ float(val) for key, val in counts.items() ]
        return res

    def split_numeric( self, attr, t ):
        split1 = self.df[ self.df[attr] >= t]
        split2 = self.df[ self.df[attr] < t ]
        return [split1, split2]


    def pick_numeric_split(self, attr):
        minv = self.df[attr].min()
        maxv = self.df[attr].max()

        delta = (maxv - minv) / self.QUANTILES

        best_splits = None
        best_h     = self.h

        for i in range( 1, self.QUANTILES ):
            t = minv + delta * i
            splits = self.split_numeric( attr, t )
            
            h = H( splits[0] ) + H( splits[1] )
            if h < best_h:
                best_h = H
                best_splits = splits

        return best_splits

    def split_nominal(self, attr):
        splits = []
        for val in self.df[ attr ].unique():
            splits.append( self.df[ self.df[attr] == val ] )
        return splits
    
    #entropy gain for an attribute
    def h_gain(self, attr):
        #see what the atribute does
        #get the splits
        #if col numerical
        #if col categorical

        splits = None



        total_size = self.df.size
        A = 0
        for split in splits:
            A += H( self.get_probs( split ) ) * split.size / total_size
        
        return self.h - A
    


    
    #choose the best atribute to split on
    def choose_attr(self):
        '''
        for every attribute determine, according to type, get the entropy gain
        choose the one with the best one

        nominal - entrop


        
        
        '''
        pass
        





#really, wrap it in a fkn class in order not to pass df all the fkn time
#oh no! i was supposed to delete that comment before uploading!
#whatever will I do now...
