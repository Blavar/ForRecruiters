# %%
'''
Well, well, well. Look who it is.
After hours of hazing at the simulation, eons of case generation (despite my friendly advice), You've arrived here.

Anyway, back to bidness.
Here at step (3) we just plot the data and take the guess with respect to it's shape.
It looks suspiciously like a graph of 1/x. So this will be our guess (due to the nature of the medium, You have no say in this matter, sorry).
Getting it's exact parameters and testing if it's any good will be the next Chapter's task.


SIDENOTE: If it's not yet evident that I'm yet to become an expert in matplotlib, or data visualization in general - it should be now.
Calculus? Sure. Algorthims? With pleasure. AI? Any day. Data visualization. Only for monetary compensation, also known as a job.
'''
import json # JAASOOOON
file = open( 'DB.json', 'r' )
data = json.load( file )

dataX = data['X']
dataY = data['Y']

# data = [ (int(key), val) for key, val in data.items() ]
# data = sorted( data, key = lambda x:x[0] )
# dataX = [x[0] for x in data]
# dataY = [y[1] for y in data]

import matplotlib.pyplot as plt
plt.scatter(dataX, dataY)
plt.show()
